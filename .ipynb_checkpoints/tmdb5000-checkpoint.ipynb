# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('./data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# ./data\tmdb_5000_credits.csv
# ./data\tmdb_5000_movies.csv

# %%
df_movies=pd.read_csv("./data/tmdb_5000_movies.csv")
df_credits=pd.read_csv("./data/tmdb_5000_credits.csv")

# %%
df_movies.shape
# Out:
# (4803, 20)

# %%
df_movies.sample(5)
# Out:
#         budget                                             genres  \
# 724   70000000  [{"id": 28, "name": "Action"}, {"id": 18, "nam...
# 1709  30000000  [{"id": 16, "name": "Animation"}, {"id": 878, ...
# 3487   6000000  [{"id": 18, "name": "Drama"}, {"id": 36, "name...
# 3491   6000000                      [{"id": 18, "name": "Drama"}]
# 637   61000000  [{"id": 18, "name": "Drama"}, {"id": 10402, "n...
#
#                                       homepage      id  \
# 724                                        NaN    9509
# 1709                                       NaN  192577
# 3487                                       NaN   13537
# 3491  http://www.sonyclassics.com/thewackness/   13990
# 637           http://www.lesmiserablesfilm.com   82695
#
#                                                keywords original_language  \
# 724   [{"id": 534, "name": "mexico"}, {"id": 591, "n...                en
# 1709                                                 []                ja
# 3487                                                 []                en
# 3491  [{"id": 10683, "name": "coming of age"}, {"id"...                en
# 637   [{"id": 254, "name": "france"}, {"id": 642, "n...                en
#
#        original_title                                           overview  \
# 724       Man on Fire  Jaded ex-CIA operative John Creasy reluctantly...
# 1709       キャプテンハーロック  Space Pirate Captain Harlock and his fearless ...
# 3487  Shattered Glass  Fact-based 2003 drama about the young journali...
# 3491     The Wackness  Set in New York City in the sweltering summer,...
# 637    Les Misérables  An adaptation of the successful stage musical ...
#
#       popularity                               production_companies  \
# 724    45.299089  [{"name": "Regency Enterprises", "id": 508}, {...
# 1709   14.726338   [{"name": "Toei Animation Company", "id": 3116}]
# 3487    6.272570  [{"name": "Lions Gate Films", "id": 35}, {"nam...
# 3491    7.161051  [{"name": "SBK Pictures", "id": 11665}, {"name...
# 637    48.356214  [{"name": "Universal Pictures", "id": 33}, {"n...
#
#                                    production_countries release_date  \
# 724   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2004-04-23
# 1709            [{"iso_3166_1": "JP", "name": "Japan"}]   2013-09-07
# 3487  [{"iso_3166_1": "CA", "name": "Canada"}, {"iso...   2003-11-14
# 3491  [{"iso_3166_1": "US", "name": "United States o...   2008-07-03
# 637   [{"iso_3166_1": "GB", "name": "United Kingdom"...   2012-12-18
#
#         revenue  runtime                                   spoken_languages  \
# 724   130293714    146.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 1709   17137302    115.0  [{"iso_639_1": "ja", "name": "\u65e5\u672c\u8a...
# 3487    2944752     94.0  [{"iso_639_1": "en", "name": "English"}, {"iso...
# 3491    2899975     99.0           [{"iso_639_1": "en", "name": "English"}]
# 637   441809770    157.0           [{"iso_639_1": "en", "name": "English"}]
#
#         status                                            tagline  \
# 724   Released  Creasy's art is death, and he is about to pain...
# 1709  Released                                                NaN
# 3487  Released                                                NaN
# 3491  Released                                                NaN
# 637   Released                          Fight. Dream. Hope. Love.
#
#                              title  vote_average  vote_count
# 724                    Man on Fire           7.3        1553
# 1709  Space Pirate Captain Harlock           6.5         356
# 3487               Shattered Glass           6.6         111
# 3491                  The Wackness           6.2          94
# 637                 Les Misérables           7.1        1884
